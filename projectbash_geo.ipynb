# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ds = pd.read_csv('/content/sample_data/CarPrice_Assignment.csv')

# %% [markdown]
# The cells below are for predicting the price of the car using only the attributes that are of integer or float datatype. The objects are not included for regression. These independant data gives more accuracy in predictions.

# %%
for x in ds:
    if ds[x].dtypes == "int64":
        ds[x] = ds[x].astype(float)
ds = ds.select_dtypes(exclude=['object'])

# %%
X = ds.iloc[:, :-1].values
y = ds.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=5)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=False,
#                       random_state=35, verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_test)

# %%
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# Accuracy: 94.22 %.
# 0.9857857999927441

# %% [markdown]
# Visualizing the Data

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks

# %% [markdown]
# Visualizing the features whose data can be labeled and counted.

# %%
ds.groupby(['symboling']).mean().reset_index().plot(kind='scatter',x='symboling',y='price',color= 'red')
plt.xlabel("Symbol",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Symbol VS Cash",color='red')
plt.show()
ds['brand'] = pd.read_csv('/content/sample_data/CarPrice_Assignment.csv').CarName.str.split(' ').str.get(0).str.upper()
ds.groupby(['brand']).mean().reset_index().plot(kind='scatter',x='brand',y='price',color= 'red')
plt.xlabel("Brand",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Brand VS Cash",color='red')
xticks(rotation = 90)
plt.show()
plt.tight_layout()
ds = pd.read_csv('/content/sample_data/CarPrice_Assignment.csv')
ds.groupby(['fueltype']).mean().reset_index().plot(kind='scatter',x='fueltype',y='price',color= 'red')
plt.xlabel("Fuel",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Fuel VS Cash",color='red')
plt.show()
ds.groupby(['aspiration']).mean().reset_index().plot(kind='scatter',x='aspiration',y='price',color= 'red')
plt.xlabel("Aspiration",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Aspiration VS Cash",color='red')
plt.show()
ds.groupby(['doornumber']).mean().reset_index().plot(kind='scatter',x='doornumber',y='price',color= 'red')
plt.xlabel("No. of doors",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Doors VS Cash",color='red')
plt.show()
ds.groupby(['carbody']).mean().reset_index().plot(kind='scatter',x='carbody',y='price',color= 'red')
plt.xlabel("CarBody",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("CarBody VS Cash",color='red')
plt.show()
ds.groupby(['drivewheel']).mean().reset_index().plot(kind='scatter',x='drivewheel',y='price',color= 'red')
plt.xlabel("Drive",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Drive VS Cash",color='red')
plt.show()
ds.groupby(['enginelocation']).mean().reset_index().plot(kind='scatter',x='enginelocation',y='price',color= 'red')
plt.xlabel("Location of engine",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("engineLocation VS Cash",color='red')
plt.show()
ds.groupby(['enginetype']).mean().reset_index().plot(kind='scatter',x='enginetype',y='price',color= 'red')
plt.xlabel("Type of engine",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Engine VS Cash",color='red')
plt.show()
ds.groupby(['cylindernumber']).mean().reset_index().plot(kind='scatter',x='cylindernumber',y='price',color= 'red')
plt.xlabel("Cylinder No.",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Cylinder VS Cash",color='red')
plt.show()
ds.groupby(['fuelsystem']).mean().reset_index().plot(kind='scatter',x='fuelsystem',y='price',color= 'red')
plt.xlabel("FuelSystem",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("FuelSystem VS Cash",color='red')
plt.show()

# %% [markdown]
# Visualizing the features whose data is either float or int.

# %%
plt.scatter(ds['wheelbase'],ds['price'],color='blue')
plt.xlabel("WheelBase",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("WheelBase VS Cash",color='red')
plt.show()
plt.scatter(ds['carlength'],ds['price'],color='blue')
plt.xlabel("Length of Car",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("CarLength VS Cash",color='red')
plt.show()
plt.scatter(ds['carwidth'],ds['price'],color='blue')
plt.xlabel("Width of car",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("CarWidth VS Cash",color='red')
plt.show()
plt.scatter(ds['carheight'],ds['price'],color='blue')
plt.xlabel("Heigth of Car",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("CarHeight VS Cash",color='red')
plt.show()
plt.scatter(ds['curbweight'],ds['price'],color='blue')
plt.xlabel("Curb Weight",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("CurbWeight VS Cash",color='red')
plt.show()
plt.scatter(ds['enginesize'],ds['price'],color='blue')
plt.xlabel("EngineSize",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("EngineSize VS Cash",color='red')
plt.show()
plt.scatter(ds['boreratio'],ds['price'],color='blue')
plt.xlabel("BoreRatio",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("BoreRatio VS Cash",color='red')
plt.show()
plt.scatter(ds['stroke'],ds['price'],color='blue')
plt.xlabel("Stroke",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Stroke VS Cash",color='red')
plt.show()
plt.scatter(ds['compressionratio'],ds['price'],color='blue')
plt.xlabel("CompressionRatio",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("CompressionRatio VS Cash",color='red')
plt.show()
plt.scatter(ds['horsepower'],ds['price'],color='blue')
plt.xlabel("HP",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("HP VS Cash",color='red')
plt.show()
plt.scatter(ds['peakrpm'],ds['price'],color='blue')
plt.xlabel("Peak_rpm",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Peak_rpm VS Cash",color='red')
plt.show()
plt.scatter(ds['citympg'],ds['price'],color='blue')
plt.xlabel("City Mileage",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("City Mileage VS Cash",color='red')
plt.show()
plt.scatter(ds['highwaympg'],ds['price'],color='blue')
plt.xlabel("Highway Mileage",color="red")
plt.ylabel("Avg Price",color="red")
plt.title("Highway Mileage VS Cash",color='red')
plt.show()

# %% [markdown]
# Predicting the car price using all the features given in the dataset

# %%
ds = pd.read_csv('/content/sample_data/CarPrice_Assignment.csv')
X = pd.get_dummies(ds)
y = np.array(X['price'])
X = X.drop('price', axis = 1)
feature_list = list(X.columns)
X = np.array(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=5)

# %%
rf = RandomForestRegressor(n_estimators =30, random_state = 42)
rf.fit(X_train,y_train)
predictions = rf.predict(X_test)
print(r2_score(y_test,predictions))
errors = abs(predictions - y_test)
mape = 100 * (errors / y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# 0.9848013501271036
# Accuracy: 93.96 %.

# %% [markdown]
# Deciding which features are important

# %%
ds = pd.read_csv('/content/sample_data/CarPrice_Assignment.csv')

# %%
y = np.array(ds['price'])
f1 = np.array(ds['symboling'])
f2 = pd.get_dummies(ds['CarName'])
f3 = pd.get_dummies(ds['fueltype'])
f4 = pd.get_dummies(ds['aspiration'])
f5 = pd.get_dummies(ds['doornumber'])
f6 = pd.get_dummies(ds['carbody'])
f7 = pd.get_dummies(ds['drivewheel'])
f8 = pd.get_dummies(ds['enginelocation'])
f9 = np.array(ds['wheelbase']) 
f10 = np.array(ds['carlength'])
f11 = np.array(ds['carwidth'])
f12 = np.array(ds['carheight'])
f13 = np.array(ds['curbweight'])
f14 = pd.get_dummies(ds['enginetype'])
f15 = pd.get_dummies(ds['cylindernumber'])
f16 = np.array(ds['enginesize'])
f17 = pd.get_dummies(ds['fuelsystem'])
f18 = np.array(ds['boreratio'])
f19 = np.array(ds['stroke'])
f20 = np.array(ds['compressionratio'])
f21 = np.array(ds['horsepower'])
f22 = np.array(ds['peakrpm'])
f23 = np.array(ds['citympg'])
f24 = np.array(ds['highwaympg'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f1.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f1accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f1\n', round(f1accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f2, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f2accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f2\n', round(f2accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f3, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f3accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f3\n', round(f3accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f4, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f4accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f4\n', round(f4accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f5, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f5accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f5\n', round(f5accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f6, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f6accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f6\n', round(f6accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f7, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f7accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f7\n', round(f7accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f8, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f8accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f8\n', round(f8accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f9.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f9accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f9\n', round(f9accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f10.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f10accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f10\n', round(f10accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f11.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f11accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f11\n', round(f11accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f12.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f12accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f12\n', round(f12accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f13.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f13accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f13\n', round(f13accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f14, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f14accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f14\n', round(f14accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f15, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f15accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f15\n', round(f15accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f16.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f16accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f16\n', round(f16accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f17, y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f17accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f17\n', round(f17accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f18.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f18accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f18\n', round(f18accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f19.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f19accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f19\n', round(f19accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f20.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f20accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f20\n', round(f20accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f21.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f21accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f21\n', round(f21accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f22.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f22accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f22\n', round(f22accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f23.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f23accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f23\n', round(f23accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f24.reshape(-1,1), y, test_size=0.05, random_state=5)

from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 1000, random_state = 35)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
errors = abs(y_pred - y_test)
mape = 100 * (errors / y_test)
f24accuracy = 100 - np.mean(mape)
print('\nAccuracy and r2 score of f24\n', round(f24accuracy, 2), '%.')
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# Accuracy and r2 score of f1
#  49.22 %.
# 0.16461711207540364
#
# Accuracy and r2 score of f2
#  78.39 %.
# 0.01801198143192473
#
# Accuracy and r2 score of f3
#  30.9 %.
# -0.06516949378484505
#
# Accuracy and r2 score of f4
#  39.07 %.
# 0.03270057590845765
#
# Accuracy and r2 score of f5
#  32.06 %.
# -0.01005871008173731
#
# Accuracy and r2 score of f6
#  45.95 %.
# 0.16622593448942502
#
# Accuracy and r2 score of f7
#  63.02 %.
# 0.48009996669156585
#
# Accuracy and r2 score of f8
#  34.85 %.
# -0.008514085765729318
#
# Accuracy and r2 score of f9
#  88.43 %.
# 0.9480437059087222
#
# Accuracy and r2 score of f10
#  87.87 %.
# 0.9094598196997746
#
# Accuracy and r2 score of f11
#  85.39 %.
# 0.8658118669696748
#
# Accuracy and r2 score of f12
#  53.68 %.
# 0.08412761011250314
#
# Accuracy and r2 score of f13
#  91.11 %.
# 0.9780644219367037
#
# Accuracy and r2 score of f14
#  42.25 %.
# 0.21891822483840062
#
# Accuracy and r2 score of f15
#  58.54 %.
# 0.598046452159772
#
# ...

# %% [markdown]
# This graph plots the individual features that has most accuracy in predicting the prices. The importance of each feature can be deducted from the graph. higher the blue dot for each feature, more important it is in predicting the price.
#
# Here i am using mean absolute percentage error to calculate accuracy. it is not the best way. Tjhere are better options.
#
# The accuracy will also vary with the model used for prediction and also with the hyperparameters and parameters used. therefore the accuracy of the features are subjected to change and are not absolute.

# %%
feature_list = ['symboling','CarName','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight','enginetype','cylindernumber',  'enginesize','fuelsystem','boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
features = [f1accuracy,f2accuracy,f3accuracy,f4accuracy,f5accuracy,f6accuracy,f7accuracy,f8accuracy,f9accuracy,f10accuracy,f11accuracy,f12accuracy,f13accuracy,f14accuracy,f15accuracy,f16accuracy,f17accuracy,f18accuracy,f19accuracy,f20accuracy,f21accuracy,f22accuracy,f23accuracy,f24accuracy]
plt.scatter(feature_list,features,color='blue')
plt.xlabel("Features",color="red")
plt.ylabel("Accuracy",color="red")
plt.title("Features VS Accuracy",color='red')
xticks(rotation = 90)
plt.show()

# %% [markdown]
# from the graph we can find some of the important price predicting featrue:
#
# * curbweight
# * wheelbase
# * carlength
# * citympg
# * carheight
# * horsepower
# * highwaympg
# * enginesize
#
# all other features are sub-80 in accuracy
